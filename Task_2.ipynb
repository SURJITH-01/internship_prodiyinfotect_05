# %% [markdown]
# <a href="https://colab.research.google.com/github/SURJITH-01/internship_prodiyinfotect_05/blob/main/Task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
data = pd.read_csv("/content/Online Sales Data.csv")
print(data.head())
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
X = data[['Total Revenue', 'Unit Price']]

# %%
wcss = []

for i in range(1,11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

plt.plot(range(1,11), wcss)
plt.xlabel("Clusters")
plt.ylabel("WCSS")
plt.show()

# %%
kmeans = KMeans(n_clusters=5, random_state=42)
y_pred = kmeans.fit_predict(X)

# %%
plt.scatter(X.iloc[:,0], X.iloc[:,1], c=y_pred)
plt.xlabel("Total Revenue")
plt.ylabel("Unit Price")
plt.show()

# %%
kmeans = KMeans(n_clusters=4, random_state=42)
y_pred = kmeans.fit_predict(X)

print(kmeans.cluster_centers_)
# Out:
# [[ 490.96087719  349.77719298]
#  [2658.792      2398.794     ]
#  [1281.23375     915.615     ]
#  [ 115.98382716   62.67796296]]

# %%
plt.scatter(X.iloc[:,0], X.iloc[:,1], c=y_pred)

plt.scatter(
    kmeans.cluster_centers_[:,0],
    kmeans.cluster_centers_[:,1],
    s=200,
    marker='X'
)

plt.xlabel("Total Revenue")
plt.ylabel("Unit Price")
plt.title("Customer Segmentation")
plt.show()

# %%
print(kmeans.cluster_centers_)
# Out:
# [[ 490.96087719  349.77719298]
#  [2658.792      2398.794     ]
#  [1281.23375     915.615     ]
#  [ 115.98382716   62.67796296]]

# %%
data['Cluster'] = y_pred
print(data.head())
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method  \
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal
#
#    Cluster
# 0        2
# 1        0
# 2        3
# 3        3
# 4        3

# %%
print(kmeans.cluster_centers_)
# Out:
# [[ 490.96087719  349.77719298]
#  [2658.792      2398.794     ]
#  [1281.23375     915.615     ]
#  [ 115.98382716   62.67796296]]
